# %%
# Viral Advertising --- 

m=5                        # people
n=int(input())             # days
count=0                    # likes
for i in range(n):
    a = m // 2             # liked by people
    count+=a               # total likes
    m=a*3                  # for next day multiply by 3
print(count)
# Out:
#  9
# 126
