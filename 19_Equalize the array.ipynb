# %%
# Equalize the array 

from collections import Counter

n=int(input())
arr = list(map(int,input().split()))

freq = Counter(arr)
deletions = len(arr) - max(freq.values())

print(deletions)
print(freq)
# Out:
#  5
#  3 3 2 1 3
# 2
# Counter({3: 3, 2: 1, 1: 1})

# %%
Sample Input

STDIN       Function
-----       --------
5           arr[] size n = 5
3 3 2 1 3   arr = [3, 3, 2, 1, 3]
Sample Output

2
