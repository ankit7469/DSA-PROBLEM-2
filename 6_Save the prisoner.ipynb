# %%
#  save the prisoner
t=int(input())                                    # testcase
for _ in range(t):
    n,m,s=map(int,input().split())                # prisoner, sweet and seat number
    
    result=((m-1)+(s-1))%n + 1                        # m-1 beacuse of making equal to indexing and s-1 because first cancy to prisoner 1
    
    if(result==0):
        print(n)
    else:
        print(result)
# Out:
#  2
#  5 2 1
# 1
#  5 2 2
# 2
