# %%
# Beautiful days at the movies ---

i,j,k=map(int,input().split())
count=0
for n in range(i,j+1):
    temp=n
    rev=0
    while temp>=0:
        last_digit=n%10                        # % for remainder ( last digit)                             
        rev=(rev*10) +last_digit               # for reverse
        temp=temp//10                                # quoteient  
        
        if (abs(n-rev))%k==0:
            count+=1
        else:
            count+=0
print(count)

# %% [markdown]
# ###### n=int(input())
# a=n%10
# b=n//10
# c=(a*10) +b
# print(c)

# %%
n=int(input())
print(n[::-1])
# Out:
#  45698
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 n=int(input())
# ----> 2 print(n[::-1])
#
# TypeError: 'int' object is not subscriptable

# %%
20 23 6

# %%
i, j, k = map(int, input().split())
count = 0

for n in range(i, j + 1):
    temp = n
    rev = 0

    while temp > 0:
        digit = temp % 10
        rev = rev * 10 + digit
        temp = temp // 10

    if abs(n - rev) % k == 0:
        count += 1

print(count)
